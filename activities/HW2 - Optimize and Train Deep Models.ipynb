# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---

# %% [markdown]
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well known problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.  https://keras.io/

# %% [markdown]
# ##Exercise 2.1: Text Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layers Neural Network to perfrom classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import tensorflow_datasets as tfds
import time

import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)
# os.environ['TF_DETERMINISTIC_OPS']='1'

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Tensorflow Dataset. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes from a larger news corups. The total number of training samples is 120,000 and testing 7,600. Each class contains 30,000 training samples and 1,900 testing samples. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.
#
# We will split the training set into two 90%-10% splits in order to have a validation set.

# %%
### NOTE ### 
# running this cell might yield download-related errors.
# just repeating the execution a couple of times should solve the error.

train_ds, valid_ds, test_ds = tfds.load('ag_news_subset',
                                        as_supervised=True, # return a set of (text, label) tuples 
                                        split=['train[:90%]', 'train[-10%:]', 'test'],
                                        batch_size=-1)  
                                        # ^ using batch_size=-1 returns Tensors instead of Dataset objects
# Out:
# Downloading and preparing dataset ag_news_subset/1.0.0 (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteGWCUY5/ag_news_subset-train.tfrecord
#   0%|          | 0/120000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteGWCUY5/ag_news_subset-test.tfrecord
#   0%|          | 0/7600 [00:00<?, ? examples/s]
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %%
# Tensors have two elements, data and labels; let's split them
# so we can transform the data
X_train, y_train = train_ds
X_valid, y_valid = valid_ds
X_test, y_test = test_ds

# %% [markdown]
# The AG News Subset dataset consists in news articles, each one composed by a sequence of words. In order to encode each article in a single tensor with a fixed number of elements, we will use multi-hot encoding. For testing purposes, we will only consider the first 10,000  most common words. Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
num_words = 1000
vectorize_layer = tf.keras.layers.TextVectorization(
 max_tokens=num_words,
 standardize="lower_and_strip_punctuation",
 split="whitespace",
 output_mode='multi_hot',
 pad_to_max_tokens=True)

vectorize_layer.adapt(X_train)

# %%
X_train = vectorize_layer(X_train)
X_valid = vectorize_layer(X_valid)
X_test  = vectorize_layer(X_test)

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (`keras.models.Sequential`) and add four layers to it by calling its `add()` method:
#
#
# *   a input layer (`tf.keras.Input`) that is the first layer in your model. With this layer you should specify the `input_shape` argument, leaving out the batch size: `(num_words,)`;
# *  a Dense layer (`keras.layers.Dense`) with 16 neurons, and the "relu" activation function;
# * another Dense layer with 16 neurons, also with the "relu" activation function;
# * a final Dense layer with 4 output neurons, and with the "softmax" activation (since we considering a classification task with four classes).

# %%
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# %% [markdown]
# Call the model's `summary()` method to check if the model has been built correctly. Also, try using `keras.utils.plot_model()` to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                16016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (`None`), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# Instaed of using `add()` method it is also possibile to define the model using the following syntax

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])
model.summary()
keras.utils.plot_model(model, "my_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                16016
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 16,356
# Trainable params: 16,356
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its `compile()` method to specify the loss function and the optimizer to use.
#
# Since the model performs a classification task, and we have labels encoded as integers, we use the sparse categorical cross-entropy loss. As optimizer we use Adam.
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify `metrics=["accuracy"]`.

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its `fit()` method, passing to it the input features (`X_train`) and the target classes (`y_train`). Set the number of epochs to 20.
# In order to validate our model we will also pass the validation data by setting `validation_data=(X_valid, y_valid)`. Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the `fit()` method will return a `History` object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.8503 - accuracy: 0.6761 - val_loss: 0.5107 - val_accuracy: 0.8314
# Epoch 2/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4583 - accuracy: 0.8449 - val_loss: 0.4452 - val_accuracy: 0.8475
# Epoch 3/20
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4222 - accuracy: 0.8546 - val_loss: 0.4318 - val_accuracy: 0.8507
# Epoch 4/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4089 - accuracy: 0.8573 - val_loss: 0.4241 - val_accuracy: 0.8509
# Epoch 5/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4012 - accuracy: 0.8590 - val_loss: 0.4210 - val_accuracy: 0.8525
# Epoch 6/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3959 - accuracy: 0.8601 - val_loss: 0.4175 - val_accuracy: 0.8531
# Epoch 7/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3917 - accuracy: 0.8615 - val_loss: 0.4149 - val_accuracy: 0.8535
# Epoch 8/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3882 - accuracy: 0.8617 - val_loss: 0.4132 - val_accuracy: 0.8550
# Epoch 9/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3851 - accuracy: 0.8627 - val_loss: 0.4109 - val_accuracy: 0.8540
# Epoch 10/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3825 - accuracy: 0.8629 - val_loss: 0.4096 - val_accuracy: 0.8534
# Epoch 11/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3799 - accuracy: 0.8637 - val_loss: 0.4081 - val_accuracy: 0.8539
# Epoch 12/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3775 - accuracy: 0.8638 - val_loss: 0.4064 - val_accuracy: 0.8543
# Epoch 13/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3753 - accuracy: 0.8645 - val_loss: 0.4051 - val_accuracy: 0.8538
# Epoch 14/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3731 - accuracy: 0.8649 - val_loss: 0.4053 - val_accuracy: 0.8543
# Epoch 15/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3709 - accuracy: 0.8660 - val_loss: 0.4035 - val_accuracy: 0.8553
# Epoch 16/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3689 - accuracy: 0.8661 - val_loss: 0.4027 - val_accuracy: 0.8553
# Epoch 17/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3669 - accuracy: 0.8668 - val_loss: 0.4011 - val_accuracy: 0.8565
# Epoch 18/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3649 - accuracy: 0.8672 - val_loss: 0.4003 - val_accuracy: 0.8554
# Epoch 19/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3630 - accuracy: 0.8679 - val_loss: 0.3992 - val_accuracy: 0.8559
# Epoch 20/20
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3612 - accuracy: 0.8684 - val_loss: 0.3993 - val_accuracy: 0.8564

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the `plot_learning_acc_and_loss` function because we will reuse it in the next steps.

# %%
def plot_learning_acc_and_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_acc_and_loss(history)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4093 - accuracy: 0.8521
# [0.40926671028137207, 0.8521052598953247]

# %% [markdown]
# [TO COMPLETE] Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in this cell.
#
# **MY ANSWER:**
# Let me explain the different types of set we need to train and evaluate our model. There are three different sets into which we can split our data:
#
# * **Training set:** it's used for learning the hidden representations (weights) of
# each node;
#
# * **Validation set:** it's used for evaluating whether the hidden representations are a good generalization of our function or not (i.e. it's not an overfitted model). The validation set plays an important role during the selection of the hyperparameters because, if it's the case that our model is overfitted, we have to change some of them to reduce the overfitting and get better performance during the evaluation of the validation set. We have to do in that way because the hyperparameters are values that cannot be learnt and must be set by the programmer (such as learning rate, number of neurons, number of epochs, etc.).
#
# * **Test set:** it's used for evaluating whether the whole model (the hidden representations and hyperparameters) is a good generalization of our function or not.
#
# Therefore, it's important to estimate the model on the test set, instead of the validation set, because the test set is a set of data which has never been seen by the model. Unlike the previous one, the validation set is not unseen data, because it has been used to select the hyperparameters and so the model has been modified to get better performance on it.
#
# As I've already said, the validation set is useful to select the hyperparameters of the model and it can be involved in a lot of techniques to choose the best ones. More specifically, these techniques take a set of hyperemeters and the output is the combination of them with the best performance obtained on the validation set. Some examples of these techniques are: grid search, random search and Bayesian optimization.

# %% [markdown]
# ## [TO COMPLETE] Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..
#
# [TO COMPLETE] In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %%
overfitted_model_learning_rate = 2e-4
overfitted_model_epochs = 50

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])
#[TO COMPLETE] modify the previuos model in order to obtain a new model that overfits the training data

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=overfitted_model_learning_rate),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=overfitted_model_epochs,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5782 - accuracy: 0.7949 - val_loss: 0.4343 - val_accuracy: 0.8484
# Epoch 2/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4111 - accuracy: 0.8541 - val_loss: 0.4195 - val_accuracy: 0.8507
# Epoch 3/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3972 - accuracy: 0.8580 - val_loss: 0.4129 - val_accuracy: 0.8518
# Epoch 4/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3880 - accuracy: 0.8595 - val_loss: 0.4060 - val_accuracy: 0.8527
# Epoch 5/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3803 - accuracy: 0.8617 - val_loss: 0.4027 - val_accuracy: 0.8536
# Epoch 6/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3729 - accuracy: 0.8636 - val_loss: 0.4009 - val_accuracy: 0.8522
# Epoch 7/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3658 - accuracy: 0.8661 - val_loss: 0.3991 - val_accuracy: 0.8545
# Epoch 8/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3591 - accuracy: 0.8683 - val_loss: 0.3959 - val_accuracy: 0.8568
# Epoch 9/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3525 - accuracy: 0.8704 - val_loss: 0.3947 - val_accuracy: 0.8572
# Epoch 10/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3460 - accuracy: 0.8727 - val_loss: 0.3939 - val_accuracy: 0.8568
# Epoch 11/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3396 - accuracy: 0.8752 - val_loss: 0.3928 - val_accuracy: 0.8581
# Epoch 12/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3335 - accuracy: 0.8776 - val_loss: 0.3918 - val_accuracy: 0.8562
# Epoch 13/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3274 - accuracy: 0.8794 - val_loss: 0.3925 - val_accuracy: 0.8563
# Epoch 14/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3213 - accuracy: 0.8825 - val_loss: 0.3947 - val_accuracy: 0.8583
# Epoch 15/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3154 - accuracy: 0.8844 - val_loss: 0.3941 - val_accuracy: 0.8563
# Epoch 16/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3097 - accuracy: 0.8865 - val_loss: 0.3939 - val_accuracy: 0.8583
# Epoch 17/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3041 - accuracy: 0.8890 - val_loss: 0.3979 - val_accuracy: 0.8571
# Epoch 18/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2982 - accuracy: 0.8905 - val_loss: 0.3966 - val_accuracy: 0.8558
# Epoch 19/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2927 - accuracy: 0.8928 - val_loss: 0.3997 - val_accuracy: 0.8571
# Epoch 20/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2869 - accuracy: 0.8954 - val_loss: 0.4065 - val_accuracy: 0.8547
# Epoch 21/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2816 - accuracy: 0.8977 - val_loss: 0.4060 - val_accuracy: 0.8587
# Epoch 22/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2761 - accuracy: 0.8999 - val_loss: 0.4082 - val_accuracy: 0.8553
# Epoch 23/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2708 - accuracy: 0.9025 - val_loss: 0.4109 - val_accuracy: 0.8553
# Epoch 24/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2660 - accuracy: 0.9037 - val_loss: 0.4157 - val_accuracy: 0.8563
# Epoch 25/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2612 - accuracy: 0.9052 - val_loss: 0.4178 - val_accuracy: 0.8575
# Epoch 26/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2563 - accuracy: 0.9077 - val_loss: 0.4214 - val_accuracy: 0.8547
# Epoch 27/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2514 - accuracy: 0.9098 - val_loss: 0.4288 - val_accuracy: 0.8533
# Epoch 28/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2472 - accuracy: 0.9113 - val_loss: 0.4323 - val_accuracy: 0.8534
# Epoch 29/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2428 - accuracy: 0.9131 - val_loss: 0.4357 - val_accuracy: 0.8535
# Epoch 30/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2384 - accuracy: 0.9145 - val_loss: 0.4402 - val_accuracy: 0.8509
# Epoch 31/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2344 - accuracy: 0.9169 - val_loss: 0.4518 - val_accuracy: 0.8518
# Epoch 32/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2307 - accuracy: 0.9186 - val_loss: 0.4537 - val_accuracy: 0.8469
# Epoch 33/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2263 - accuracy: 0.9198 - val_loss: 0.4594 - val_accuracy: 0.8489
# Epoch 34/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2227 - accuracy: 0.9213 - val_loss: 0.4628 - val_accuracy: 0.8494
# Epoch 35/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2192 - accuracy: 0.9223 - val_loss: 0.4653 - val_accuracy: 0.8493
# Epoch 36/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2157 - accuracy: 0.9239 - val_loss: 0.4734 - val_accuracy: 0.8481
# Epoch 37/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2121 - accuracy: 0.9250 - val_loss: 0.4863 - val_accuracy: 0.8457
# Epoch 38/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.2089 - accuracy: 0.9270 - val_loss: 0.4850 - val_accuracy: 0.8468
# Epoch 39/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2058 - accuracy: 0.9279 - val_loss: 0.4923 - val_accuracy: 0.8483
# Epoch 40/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.2032 - accuracy: 0.9291 - val_loss: 0.4997 - val_accuracy: 0.8467
# Epoch 41/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.1997 - accuracy: 0.9306 - val_loss: 0.5030 - val_accuracy: 0.8457
# Epoch 42/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.1964 - accuracy: 0.9315 - val_loss: 0.5110 - val_accuracy: 0.8472
# Epoch 43/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1936 - accuracy: 0.9320 - val_loss: 0.5156 - val_accuracy: 0.8442
# Epoch 44/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1910 - accuracy: 0.9339 - val_loss: 0.5222 - val_accuracy: 0.8441
# Epoch 45/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1882 - accuracy: 0.9350 - val_loss: 0.5315 - val_accuracy: 0.8417
# Epoch 46/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.1856 - accuracy: 0.9358 - val_loss: 0.5373 - val_accuracy: 0.8428
# Epoch 47/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1827 - accuracy: 0.9366 - val_loss: 0.5463 - val_accuracy: 0.8424
# Epoch 48/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.1802 - accuracy: 0.9374 - val_loss: 0.5544 - val_accuracy: 0.8416
# Epoch 49/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1777 - accuracy: 0.9386 - val_loss: 0.5545 - val_accuracy: 0.8413
# Epoch 50/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.1753 - accuracy: 0.9397 - val_loss: 0.5684 - val_accuracy: 0.8407
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5772 - accuracy: 0.8361
# [0.5771549940109253, 0.836052656173706]

# %% [markdown]
# Define the `plot_learning_curves` function that plots only the losses (not the accuracy).

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.epoch,history.history['loss'], label='train loss')
    plt.plot(history.epoch,history.history['val_loss'], label='valid loss')
    plt.legend()
    plt.title('loss')
    plt.grid(True)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### [TO COMPLETE] L1 norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow to remove the overfitting effect.

# %%
#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfroms the L1-norm regularization

#[TO COMPLETE] copy the model that you previously defined that overfits the 
#training data, and add the L1-norm regularization. Use a proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1 

#In general, a layer that exploits L1-norm regularization is defined as follows:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE], kernel_regularizer=tf.keras.regularizers.l1([TO COMPLETE]))) 

l1_regularization = tf.keras.regularizers.l1(7e-4)

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(32, activation="relu", kernel_regularizer=l1_regularization),
    keras.layers.Dense(32, activation="relu", kernel_regularizer=l1_regularization),
    keras.layers.Dense(4, activation="softmax", kernel_regularizer=l1_regularization)
])
#[TO COMPLETE]


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=overfitted_model_learning_rate),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=overfitted_model_epochs,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 9s 2ms/step - loss: 0.9968 - accuracy: 0.7853 - val_loss: 0.7713 - val_accuracy: 0.8371
# Epoch 2/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.7321 - accuracy: 0.8426 - val_loss: 0.7148 - val_accuracy: 0.8443
# Epoch 3/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6905 - accuracy: 0.8465 - val_loss: 0.6865 - val_accuracy: 0.8436
# Epoch 4/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6649 - accuracy: 0.8487 - val_loss: 0.6678 - val_accuracy: 0.8428
# Epoch 5/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6456 - accuracy: 0.8498 - val_loss: 0.6490 - val_accuracy: 0.8478
# Epoch 6/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6297 - accuracy: 0.8507 - val_loss: 0.6375 - val_accuracy: 0.8468
# Epoch 7/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6168 - accuracy: 0.8520 - val_loss: 0.6285 - val_accuracy: 0.8480
# Epoch 8/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6060 - accuracy: 0.8525 - val_loss: 0.6124 - val_accuracy: 0.8506
# Epoch 9/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5960 - accuracy: 0.8534 - val_loss: 0.6071 - val_accuracy: 0.8481
# Epoch 10/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5878 - accuracy: 0.8531 - val_loss: 0.5989 - val_accuracy: 0.8484
# Epoch 11/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5809 - accuracy: 0.8538 - val_loss: 0.5898 - val_accuracy: 0.8508
# Epoch 12/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5745 - accuracy: 0.8540 - val_loss: 0.5840 - val_accuracy: 0.8505
# Epoch 13/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5689 - accuracy: 0.8543 - val_loss: 0.5771 - val_accuracy: 0.8504
# Epoch 14/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5638 - accuracy: 0.8551 - val_loss: 0.5787 - val_accuracy: 0.8498
# Epoch 15/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5600 - accuracy: 0.8550 - val_loss: 0.5709 - val_accuracy: 0.8484
# Epoch 16/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5566 - accuracy: 0.8546 - val_loss: 0.5679 - val_accuracy: 0.8508
# Epoch 17/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5536 - accuracy: 0.8554 - val_loss: 0.5651 - val_accuracy: 0.8516
# Epoch 18/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5510 - accuracy: 0.8555 - val_loss: 0.5633 - val_accuracy: 0.8509
# Epoch 19/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5484 - accuracy: 0.8549 - val_loss: 0.5591 - val_accuracy: 0.8521
# Epoch 20/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5460 - accuracy: 0.8553 - val_loss: 0.5624 - val_accuracy: 0.8528
# Epoch 21/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5443 - accuracy: 0.8552 - val_loss: 0.5563 - val_accuracy: 0.8521
# Epoch 22/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5420 - accuracy: 0.8561 - val_loss: 0.5573 - val_accuracy: 0.8509
# Epoch 23/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5396 - accuracy: 0.8561 - val_loss: 0.5516 - val_accuracy: 0.8529
# Epoch 24/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5382 - accuracy: 0.8559 - val_loss: 0.5501 - val_accuracy: 0.8527
# Epoch 25/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5366 - accuracy: 0.8564 - val_loss: 0.5479 - val_accuracy: 0.8545
# Epoch 26/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5353 - accuracy: 0.8559 - val_loss: 0.5478 - val_accuracy: 0.8540
# Epoch 27/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5338 - accuracy: 0.8566 - val_loss: 0.5464 - val_accuracy: 0.8534
# Epoch 28/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5327 - accuracy: 0.8568 - val_loss: 0.5439 - val_accuracy: 0.8537
# Epoch 29/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5312 - accuracy: 0.8566 - val_loss: 0.5403 - val_accuracy: 0.8554
# Epoch 30/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5297 - accuracy: 0.8568 - val_loss: 0.5399 - val_accuracy: 0.8551
# Epoch 31/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5287 - accuracy: 0.8567 - val_loss: 0.5421 - val_accuracy: 0.8543
# Epoch 32/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5278 - accuracy: 0.8568 - val_loss: 0.5403 - val_accuracy: 0.8527
# Epoch 33/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5262 - accuracy: 0.8571 - val_loss: 0.5411 - val_accuracy: 0.8543
# Epoch 34/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5254 - accuracy: 0.8567 - val_loss: 0.5377 - val_accuracy: 0.8535
# Epoch 35/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5247 - accuracy: 0.8568 - val_loss: 0.5378 - val_accuracy: 0.8536
# Epoch 36/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5232 - accuracy: 0.8570 - val_loss: 0.5339 - val_accuracy: 0.8535
# Epoch 37/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5221 - accuracy: 0.8577 - val_loss: 0.5383 - val_accuracy: 0.8526
# Epoch 38/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5208 - accuracy: 0.8570 - val_loss: 0.5314 - val_accuracy: 0.8545
# Epoch 39/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5197 - accuracy: 0.8572 - val_loss: 0.5311 - val_accuracy: 0.8552
# Epoch 40/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5187 - accuracy: 0.8577 - val_loss: 0.5324 - val_accuracy: 0.8550
# Epoch 41/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5176 - accuracy: 0.8579 - val_loss: 0.5304 - val_accuracy: 0.8550
# Epoch 42/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5171 - accuracy: 0.8573 - val_loss: 0.5305 - val_accuracy: 0.8558
# Epoch 43/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5164 - accuracy: 0.8572 - val_loss: 0.5309 - val_accuracy: 0.8536
# Epoch 44/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5153 - accuracy: 0.8575 - val_loss: 0.5292 - val_accuracy: 0.8516
# Epoch 45/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5149 - accuracy: 0.8575 - val_loss: 0.5297 - val_accuracy: 0.8538
# Epoch 46/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5139 - accuracy: 0.8579 - val_loss: 0.5284 - val_accuracy: 0.8548
# Epoch 47/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5133 - accuracy: 0.8574 - val_loss: 0.5272 - val_accuracy: 0.8539
# Epoch 48/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5124 - accuracy: 0.8580 - val_loss: 0.5253 - val_accuracy: 0.8547
# Epoch 49/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5113 - accuracy: 0.8577 - val_loss: 0.5243 - val_accuracy: 0.8546
# Epoch 50/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5109 - accuracy: 0.8580 - val_loss: 0.5266 - val_accuracy: 0.8526
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.8464

# %% [markdown]
# ### [TO COMPLETE] L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainig data, and add the L2-norm regularization. Use proper values for the
#alpha hyper-parameters, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1

#In general, a layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE],kernel_regularizer=tf.keras.regularizers.l2([TO COMPLETE]))) 

l2_regularization = tf.keras.regularizers.l2(5e-3)

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(32, activation="relu", kernel_regularizer=l2_regularization),
    keras.layers.Dense(32, activation="relu", kernel_regularizer=l2_regularization),
    keras.layers.Dense(4, activation="softmax", kernel_regularizer=l2_regularization)
])
#[TO COMPLETE]

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=overfitted_model_learning_rate),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=overfitted_model_epochs,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.8963 - accuracy: 0.7899 - val_loss: 0.7219 - val_accuracy: 0.8411
# Epoch 2/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6991 - accuracy: 0.8454 - val_loss: 0.6961 - val_accuracy: 0.8443
# Epoch 3/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6844 - accuracy: 0.8473 - val_loss: 0.6893 - val_accuracy: 0.8427
# Epoch 4/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6791 - accuracy: 0.8475 - val_loss: 0.6876 - val_accuracy: 0.8400
# Epoch 5/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6764 - accuracy: 0.8480 - val_loss: 0.6836 - val_accuracy: 0.8453
# Epoch 6/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6742 - accuracy: 0.8477 - val_loss: 0.6839 - val_accuracy: 0.8452
# Epoch 7/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6729 - accuracy: 0.8482 - val_loss: 0.6838 - val_accuracy: 0.8446
# Epoch 8/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6720 - accuracy: 0.8480 - val_loss: 0.6791 - val_accuracy: 0.8465
# Epoch 9/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6710 - accuracy: 0.8475 - val_loss: 0.6805 - val_accuracy: 0.8425
# Epoch 10/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6705 - accuracy: 0.8482 - val_loss: 0.6812 - val_accuracy: 0.8448
# Epoch 11/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6699 - accuracy: 0.8481 - val_loss: 0.6776 - val_accuracy: 0.8447
# Epoch 12/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6692 - accuracy: 0.8481 - val_loss: 0.6771 - val_accuracy: 0.8448
# Epoch 13/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6688 - accuracy: 0.8486 - val_loss: 0.6759 - val_accuracy: 0.8439
# Epoch 14/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6680 - accuracy: 0.8485 - val_loss: 0.6784 - val_accuracy: 0.8463
# Epoch 15/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6676 - accuracy: 0.8489 - val_loss: 0.6753 - val_accuracy: 0.8434
# Epoch 16/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6672 - accuracy: 0.8488 - val_loss: 0.6748 - val_accuracy: 0.8450
# Epoch 17/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6668 - accuracy: 0.8490 - val_loss: 0.6755 - val_accuracy: 0.8479
# Epoch 18/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6664 - accuracy: 0.8483 - val_loss: 0.6749 - val_accuracy: 0.8448
# Epoch 19/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6662 - accuracy: 0.8492 - val_loss: 0.6734 - val_accuracy: 0.8472
# Epoch 20/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6655 - accuracy: 0.8489 - val_loss: 0.6779 - val_accuracy: 0.8482
# Epoch 21/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6656 - accuracy: 0.8485 - val_loss: 0.6745 - val_accuracy: 0.8443
# Epoch 22/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6652 - accuracy: 0.8495 - val_loss: 0.6749 - val_accuracy: 0.8453
# Epoch 23/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6647 - accuracy: 0.8492 - val_loss: 0.6740 - val_accuracy: 0.8446
# Epoch 24/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6646 - accuracy: 0.8486 - val_loss: 0.6732 - val_accuracy: 0.8472
# Epoch 25/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6644 - accuracy: 0.8495 - val_loss: 0.6721 - val_accuracy: 0.8470
# Epoch 26/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6642 - accuracy: 0.8493 - val_loss: 0.6730 - val_accuracy: 0.8450
# Epoch 27/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6640 - accuracy: 0.8495 - val_loss: 0.6725 - val_accuracy: 0.8455
# Epoch 28/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6641 - accuracy: 0.8497 - val_loss: 0.6721 - val_accuracy: 0.8457
# Epoch 29/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6638 - accuracy: 0.8492 - val_loss: 0.6699 - val_accuracy: 0.8473
# Epoch 30/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6633 - accuracy: 0.8494 - val_loss: 0.6708 - val_accuracy: 0.8484
# Epoch 31/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6633 - accuracy: 0.8491 - val_loss: 0.6730 - val_accuracy: 0.8468
# Epoch 32/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6633 - accuracy: 0.8499 - val_loss: 0.6731 - val_accuracy: 0.8462
# Epoch 33/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6627 - accuracy: 0.8500 - val_loss: 0.6730 - val_accuracy: 0.8480
# Epoch 34/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6628 - accuracy: 0.8496 - val_loss: 0.6715 - val_accuracy: 0.8474
# Epoch 35/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6628 - accuracy: 0.8499 - val_loss: 0.6740 - val_accuracy: 0.8451
# Epoch 36/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6625 - accuracy: 0.8501 - val_loss: 0.6703 - val_accuracy: 0.8472
# Epoch 37/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6623 - accuracy: 0.8499 - val_loss: 0.6744 - val_accuracy: 0.8469
# Epoch 38/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6621 - accuracy: 0.8499 - val_loss: 0.6699 - val_accuracy: 0.8477
# Epoch 39/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6619 - accuracy: 0.8504 - val_loss: 0.6712 - val_accuracy: 0.8482
# Epoch 40/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6618 - accuracy: 0.8499 - val_loss: 0.6718 - val_accuracy: 0.8462
# Epoch 41/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6616 - accuracy: 0.8504 - val_loss: 0.6717 - val_accuracy: 0.8487
# Epoch 42/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6616 - accuracy: 0.8503 - val_loss: 0.6726 - val_accuracy: 0.8482
# Epoch 43/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6617 - accuracy: 0.8501 - val_loss: 0.6729 - val_accuracy: 0.8471
# Epoch 44/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6613 - accuracy: 0.8498 - val_loss: 0.6710 - val_accuracy: 0.8468
# Epoch 45/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6614 - accuracy: 0.8503 - val_loss: 0.6715 - val_accuracy: 0.8474
# Epoch 46/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6611 - accuracy: 0.8507 - val_loss: 0.6723 - val_accuracy: 0.8463
# Epoch 47/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6612 - accuracy: 0.8505 - val_loss: 0.6713 - val_accuracy: 0.8464
# Epoch 48/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6610 - accuracy: 0.8505 - val_loss: 0.6703 - val_accuracy: 0.8453
# Epoch 49/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6607 - accuracy: 0.8509 - val_loss: 0.6699 - val_accuracy: 0.8473
# Epoch 50/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.6610 - accuracy: 0.8511 - val_loss: 0.6728 - val_accuracy: 0.8470
# Model Evaluation
# 238/238 [==============================] - 1s 2ms/step - loss: 0.6794 - accuracy: 0.8405

# %% [markdown]
# ###[TO COMPLETE] Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (`patience` hyper-parameter), it stops the training phase.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainnig data
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(4, activation="softmax")
])


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=overfitted_model_learning_rate), #[TO COMPLETE] learning rate
              metrics=["accuracy"])

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the early stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=4), #[TO COMPLETE] play with patience and find the value that prevents the model from overfitting.


    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train, y_train, epochs=overfitted_model_epochs,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.5720 - accuracy: 0.7943 - val_loss: 0.4281 - val_accuracy: 0.8499
# Epoch 2/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4056 - accuracy: 0.8556 - val_loss: 0.4161 - val_accuracy: 0.8522
# Epoch 3/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3932 - accuracy: 0.8589 - val_loss: 0.4130 - val_accuracy: 0.8521
# Epoch 4/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3850 - accuracy: 0.8606 - val_loss: 0.4062 - val_accuracy: 0.8528
# Epoch 5/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3782 - accuracy: 0.8630 - val_loss: 0.4034 - val_accuracy: 0.8546
# Epoch 6/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3713 - accuracy: 0.8645 - val_loss: 0.4008 - val_accuracy: 0.8537
# Epoch 7/50
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3645 - accuracy: 0.8670 - val_loss: 0.3996 - val_accuracy: 0.8553
# Epoch 8/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3578 - accuracy: 0.8687 - val_loss: 0.3962 - val_accuracy: 0.8563
# Epoch 9/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3511 - accuracy: 0.8710 - val_loss: 0.3958 - val_accuracy: 0.8563
# Epoch 10/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3445 - accuracy: 0.8734 - val_loss: 0.3956 - val_accuracy: 0.8561
# Epoch 11/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3377 - accuracy: 0.8760 - val_loss: 0.3941 - val_accuracy: 0.8587
# Epoch 12/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3310 - accuracy: 0.8786 - val_loss: 0.3929 - val_accuracy: 0.8597
# Epoch 13/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3244 - accuracy: 0.8811 - val_loss: 0.3943 - val_accuracy: 0.8581
# Epoch 14/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3176 - accuracy: 0.8840 - val_loss: 0.3954 - val_accuracy: 0.8583
# Epoch 15/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3112 - accuracy: 0.8863 - val_loss: 0.3958 - val_accuracy: 0.8570
# Epoch 16/50
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3052 - accuracy: 0.8888 - val_loss: 0.3963 - val_accuracy: 0.8589
# Model Evaluation
# 238/238 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8566

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(4, activation="softmax")
                                     ])
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train, y_train,
                        validation_data=(X_valid, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
    print("evaluation on test set")
    model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.8467 - accuracy: 0.6874 - val_loss: 0.5046 - val_accuracy: 0.8340
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4544 - accuracy: 0.8446 - val_loss: 0.4450 - val_accuracy: 0.8475
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4203 - accuracy: 0.8537 - val_loss: 0.4310 - val_accuracy: 0.8498
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4071 - accuracy: 0.8567 - val_loss: 0.4227 - val_accuracy: 0.8508
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3996 - accuracy: 0.8588 - val_loss: 0.4193 - val_accuracy: 0.8516
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3944 - accuracy: 0.8601 - val_loss: 0.4160 - val_accuracy: 0.8524
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3904 - accuracy: 0.8612 - val_loss: 0.4137 - val_accuracy: 0.8531
# Epoch 8/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3869 - accuracy: 0.8615 - val_loss: 0.4120 - val_accuracy: 0.8542
# Epoch 9/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3839 - accuracy: 0.8623 - val_loss: 0.4095 - val_accuracy: 0.8547
# Epoch 10/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3812 - accuracy: 0.8624 - val_loss: 0.4084 - val_accuracy: 0.8550
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8493
# Epoch 1/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4643 - accuracy: 0.8306 - val_loss: 0.4359 - val_accuracy: 0.8462
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.4096 - accuracy: 0.8509 - val_loss: 0.4190 - val_accuracy: 0.8502
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3899 - accuracy: 0.8597 - val_loss: 0.4103 - val_accuracy: 0.8524
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3747 - accuracy: 0.8646 - val_loss: 0.4130 - val_accuracy: 0.8538
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3630 - accuracy: 0.8688 - val_loss: 0.4293 - val_accuracy: 0.8510
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4392 - accuracy: 0.8412
# Epoch 1/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.6563 - accuracy: 0.7706 - val_loss: 0.5774 - val_accuracy: 0.7857
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.7391 - accuracy: 0.7150 - val_loss: 0.6771 - val_accuracy: 0.7847
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.7370 - accuracy: 0.7619 - val_loss: 0.7410 - val_accuracy: 0.7712
# evaluation on test set
# 238/238 [==============================] - 1s 2ms/step - loss: 0.7269 - accuracy: 0.7684

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_acc_and_loss(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# ### [TO COMPLETE] GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`.

# %% [markdown]
# Let's Create a `build_model()` function that takes two arguments, `n_neurons` and `learning_rate`, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time requirements of the process we will consider only these two hyper-paramters.
#
# [TO COMPLETE] in the following code cell define the `build_model` function.

# %%
def build_model(n_units=30, learning_rate=1e-3):
    # The function has to build a model similar to the ones we used in previuous execises:
    #- a input layer 
    #- one or two Dense layers composed of n_units and that exploit Relu activation function 
    #- the output layer that uses the softmax activation function
    # Then, the model has to be compiled.
    #[TO COMPLETE]
    model = keras.models.Sequential([
       tf.keras.Input(shape=(num_words,)),
        keras.layers.Dense(n_units, activation="relu"),
        keras.layers.Dense(n_units, activation="relu"),
        keras.layers.Dense(4, activation="softmax")                                
    ])
    
    # [TO COMPLETE] Then, the model has to be compiled.
    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
    
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [8, 16, 24],# [TO COMPLETE] insert a list that contains few (2 or 3) reasonable value
    "learning_rate": [5e-3, 1e-4, 5e-5] #[TO COMPLETE] insert a list that contains few (2 or 3) reasonable values
    #Check how the time required to perform GRID search increases when increasing the number of values for each hyper-parameter.
}

# %% [markdown]
# Use a `sklearn.model_selection.GridSearchCV` to search the hyperparameter space of your `KerasRegressor`

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train.numpy(), y_train.numpy(), epochs=5,#The number of epochs can be modified (check what happens by increasing it)
                validation_data=(X_valid.numpy(), y_val
# 675/675 [==============================] - 1s 1ms/step - loss: 0.4405 - accuracy: 0.8478
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 1.0513 - accuracy: 0.6209 - val_loss: 0.6717 - val_accuracy: 0.7923
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5585 - accuracy: 0.8158 - val_loss: 0.5062 - val_accuracy: 0.8273
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4713 - accuracy: 0.8388 - val_loss: 0.4665 - val_accuracy: 0.8393
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4413 - accuracy: 0.8472 - val_loss: 0.4492 - val_accuracy: 0.8428
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4254 - accuracy: 0.8520 - val_loss: 0.4399 - val_accuracy: 0.8460
# 675/675 [==============================] - 1s 2ms/step - loss: 0.4242 - accuracy: 0.8530
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 1.0387 - accuracy: 0.6273 - val_loss: 0.6835 - val_accuracy: 0.7881
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5685 - accuracy: 0.8172 - val_loss: 0.5115 - val_accuracy: 0.8301
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4745 - accuracy: 0.8399 - val_loss: 0.4677 - val_accuracy: 0.8416
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4416 - accuracy: 0.8485 - val_loss: 0.4492 - val_accuracy: 0.8457
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4248 - accuracy: 0.8532 - val_loss: 0.4398 - val_accuracy: 0.8482
# 675/675 [==============================] - 1s 2ms/step - loss: 0.4328 - accuracy: 0.8487
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 1.1138 - accuracy: 0.5698 - val_loss: 0.7354 - val_accuracy: 0.7867
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5762 - accuracy: 0.8212 - val_loss: 0.5074 - val_accuracy: 0.8327
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4641 - accuracy: 0.8440 - val_loss: 0.4628 - val_accuracy: 0.8422
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4319 - accuracy: 0.8517 - val_loss: 0.4459 - val_accuracy: 0.8466
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4162 - accuracy: 0.8556 - val_loss: 0.4365 - val_accuracy: 0.8489
# 675/675 [==============================] - 1s 2ms/step - loss: 0.4380 - accuracy: 0.8466
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 1.1014 - accuracy: 0.6158 - val_loss: 0.7153 - val_accuracy: 0.7969
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5748 - accuracy: 0.8182 - val_loss: 0.5074 - val_accuracy: 0.8313
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4711 - accuracy: 0.8394 - val_loss: 0.4634 - val_accuracy: 0.8445
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4389 - accuracy: 0.8477 - val_loss: 0.4456 - val_accuracy: 0.8493
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4228 - accuracy: 0.8522 - val_loss: 0.4356 - val_accuracy: 0.8496
# 675/675 [==============================] - 1s 2ms/step - loss: 0.4236 - accuracy: 0.8548
# Epoch 1/5
# 2700/2700 [==============================] - 7s 2ms/step - loss: 1.0639 - accuracy: 0.6105 - val_loss: 0.6639 - val_accuracy: 0.7960
# Epoch 2/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.5483 - accuracy: 0.8196 - val_loss: 0.4989 - val_accuracy: 0.8311
# Epoch 3/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4628 - accuracy: 0.8418 - val_loss: 0.4606 - val_accuracy: 0.8440
# Epoch 4/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4330 - accuracy: 0.8504 - val_loss: 0.4440 - val_accuracy: 0.8472
# Epoch 5/5
# 2700/2700 [==============================] - 6s 2ms/step - loss: 0.4173 - accuracy: 0.8544 - val_loss: 0.4350 - val_accuracy: 0.8487
# 675/675 [==============================] - 1s 2ms/step - loss: 0.4325 - accuracy: 0.8472
# Epoch 1/5
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.7660 - accuracy: 0.7280 - val_loss: 0.4805 - val_accuracy: 0.8355
# Epoch 2/5
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4394 - accuracy: 0.8472 - val_loss: 0.4364 - val_accuracy: 0.8477
# Epoch 3/5
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4120 - accuracy: 0.8547 - val_loss: 0.4263 - val_accuracy: 0.8509
# Epoch 4/5
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.4011 - accuracy: 0.8575 - val_loss: 0.4191 - val_accuracy: 0.8528
# Epoch 5/5
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3946 - accuracy: 0.8596 - val_loss: 0.4162 - val_accuracy: 0.8532
# GridSearchCV(estimator=<keras.wrappers.scikit_learn.KerasRegressor object at 0x7f2ff4702090>,
#              param_grid={'learning_rate': [0.005, 0.0001, 5e-05],
#                          'n_units': [8, 16, 24]})

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test, y_test)
# Out:
# {'learning_rate': 0.0001, 'n_units': 24}
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4243 - accuracy: 0.8478
# [0.42433950304985046, 0.847763180732727]
